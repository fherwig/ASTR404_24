# %% [markdown]
# # Homework 1
#
# Please read carefully the important information in [HW-teams.md](HW-teams.md)!!
#
#
# **Due:** 02/15 9pm (I will copy the notebooks at that time as described in `HW-teams.md` and any changes made after that are ignored)

# %% [markdown]
# ## 1. Massive stars
#
# 1. Consider the $20\mathrm{M}_\odot$, $Z=0.01$ NuGrid stellar model. Make a Hertzsprung-Russel diagram and a Kippenhahn diagram as well as a $\rho_\mathrm{c}$ - $T_\mathrm{c}$ diagram. Mark on all three diagrams the location of the start of H, He, C and O burning.
# 2. In the MESA profile data you find the variable `velocity` in units of `cm/s`, which is the radial velocity due to an acceleration that results from an imbalance in the momentum equation. Investigate the evolution of this radial velocity in what will end up as the Fe core as the star evolves towards the supernova explosion. Describe the conditions in the core near the very end of the computed model sequence. What is the maximum inward velocity? A good model sequence to consider are models 1N100 where N $\in[2,3,4 \dots 9]$.
# 4. Find all isotopes that have mass fractions larger than $0.01$ at mass coordinate $0.5\mathrm{M}_\odot$  and $1.83\mathrm{M}_\odot$ at model `19100`. Confirm your finding by creating a `pt.abu_chart` plot which is available from a nugridse.se instance.
# 5. Make abundance plots for the model `19100` including the five most abundance species at mass coordinate $0.5\mathrm{M}_\odot$ and the 10 most abundant species at  $1.83\mathrm{M}_\odot$. Describe the abundance profiles around mass coordinate $1.83\mathrm{M}_\odot$ and correlate it with the velocity plot at the same model. Interpret your finding.
# 6. The mass coordinate $1.83\mathrm{M}_\odot$ is the final remnant mass according to the _rapid_ explosion model desribed in Pignatari etal (2016, ApJS 225:24), see table 8. The _delayed_ model assumes more accretion before explosion and therefore a larger remnant mass of  $2.73\mathrm{M}_\odot$. Calculate for both remnant masses the binding energy of the ejected material and express your answer in `foe` ($10^{51}\mathrm{erg}$). Perform this calculation by using the structure profiles available from the NuGrid data. Perform the calculation as well in an approximate way similar to how we did it in the quiz. Compare your results.

# %% [markdown]
# ### Comments on solution
#
# * Look for string `#FH` for my comments in your notebooks.
# * C burning does not start where C is decreasing for the first time. This may be during He burning, actually, but that is **not** what is considered the C-burning phase where most energy is generated by the C12+C12 reaction.
# * units for velocities: km/s
# * correlation between velocity plot and abundance plot: be clear what the dominant pressure is and why it is failing; clearly the increasing infall velocity is associated with the Fe core, and no nuclear burning can take place there anymore, and thus the pressure support through either radiation pressure or gas pressure will be insufficient; then the core is left with degenerate electron pressure as using results from problem would show, and at the high T and $\rho$ of the core Fe group elements are capturing electrons

# %% [markdown]
# ## 2. Equation of state
# **a.** Create a $\rho$ - $T$ diagram and add the follwing **profiles**:
#
# * $20\mathrm{M}_\odot$, $Z=0.01$  model star, model `19100` investigated in the previous problem
# * a white dwarf model of your choice along the section of the HRD  track of the (initially)  $1\mathrm{M}_\odot$, $Z=0.0001$ model sequence when `log_Teff > 4.75` and `log_L <2.0`
# * a $1\mathrm{M}_\odot$ and $20\mathrm{M}_\odot$, $Z=0.01$ model during the main-sequence evolution
#
# Add as well as the time evolution of the central conditions for the $Z=0.01$ $1\mathrm{M}_\odot$,  $9\mathrm{M}_\odot$ and $20\mathrm{M}_\odot$ stellar evolution tracks.
#
# **b.** Determine and plot the EOS separation lines in the $\rho$ - $T$ diagram that separate the regions dominated by radiation pressure, degenerate pressure and ideal gas.
#
# **c.** Describe for each of the profiles and central condition evolutions by which type of equation of state they are dominated. Interpret features you notice in these plots, such as reversal of directions or crossings of EOS separation lines.

# %% [markdown]
# ### Comments on solution
# * the reliable way to find the main-sequence would be to plot central H and Kippenhahn as a function of model number
